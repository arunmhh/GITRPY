# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv(r"D:\Project Python\4 GitPush\california_housing_train.csv")

# %%
train.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
mnist = pd.read_csv(r'D:\Project Python\4 GitPush\mnist_test.csv')

# %%
train.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
train.tail(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
train.apply(np.sqrt)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0            NaN  5.847222            3.872983    74.913283       35.818989
# 1            NaN  5.865151            4.358899    87.464278       43.600459
# 2            NaN  5.804309            4.123106    26.832816       13.190906
# 3            NaN  5.800000            3.741657    38.742741       18.357560
# 4            NaN  5.793962            4.472136    38.131352       18.055470
# ...          ...       ...                 ...          ...             ...
# 16995        NaN  6.370243            7.211103    47.085029       19.849433
# 16996        NaN  6.378871            6.000000    48.466483       22.978251
# 16997        NaN  6.468385            4.123106    51.739733       23.043437
# 16998        NaN  6.465292            4.358899    51.691392       23.494680
# 16999        NaN  6.367103            7.211103    42.661458       17.320508
#
# ...

# %%
train.apply(np.sum, axis=0)
# Out:
# longitude            -2.032556e+06
# latitude              6.056288e+05
# housing_median_age    4.860190e+05
# total_rooms           4.494230e+07
# total_bedrooms        9.169984e+06
# population            2.430276e+07
# households            8.520773e+06
# median_income         6.602083e+04
# median_house_value    3.524116e+09
# dtype: float64

# %%
train.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
train.drop_duplicates()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
TT = train[['longitude', 'latitude', 'median_income', 'population']] # column subsetting

# %%
TT
# Out:
#        longitude  latitude  median_income  population
# 0        -114.31     34.19         1.4936      1015.0
# 1        -114.47     34.40         1.8200      1129.0
# 2        -114.56     33.69         1.6509       333.0
# 3        -114.57     33.64         3.1917       515.0
# 4        -114.57     33.57         1.9250       624.0
# ...          ...       ...            ...         ...
# 16995    -124.26     40.58         2.3571       907.0
# 16996    -124.27     40.69         2.5179      1194.0
# 16997    -124.30     41.84         3.0313      1244.0
# 16998    -124.30     41.80         1.9797      1298.0
# 16999    -124.35     40.54         3.0147       806.0
#
# [17000 rows x 4 columns]

# %%
pd.value_counts(TT['longitude']).plot.bar()
# Out:
# <AxesSubplot:>

# %%
TT.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
TT.plot.scatter(x= 'median_income', y= 'population')
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='population'>

# %%
boxplot = TT.boxplot(column=['median_income', 'longitude', 
'population', 'latitude'])

# %%
boxplot = TT.boxplot(column=['population'])
